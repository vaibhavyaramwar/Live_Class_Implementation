# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
aa=df.dtypes[df.dtypes == object].index

# %%
aa
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df_object_Col=df[aa]

# %%
df_object_Col.describe()
# Out:
#                              Name   Sex  Ticket    Cabin Embarked
# count                         891   891     891      204      889
# unique                        891     2     681      147        3
# top     Shutes, Miss. Elizabeth W  male  347082  B96 B98        S
# freq                            1   577       7        4      644

# %%
df["testcol"] = "testcheck"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked    testcol
# 0        0         A/5 21171   7.2500   NaN        S  testcheck
# 1        0          PC 17599  71.2833   C85        C  testcheck
# 2        0  STON/O2. 3101282   7.9250   NaN        S  testcheck
# 3        0            113803  53.1000  C123        S  testcheck
# 4        0            373450   8.0500   NaN        S  testcheck
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S  testcheck
# 887      0            112053  30.0000   B42        S  testcheck
# 888      2        W./C. 6607  23.4500   NaN        S  testcheck
# 889      0            111369  30.0000  C148        C  testcheck
# 890      0            370376   7.7500   NaN        Q  testcheck
#
# [891 rows x 13 columns]

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][::-1]
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# testcol          0
# dtype: int64

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
df.iloc[df[df['Age'].isnull() == True].index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked    testcol
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  testcheck
# 17     male  NaN      0      0      244373  13.0000   NaN        S  testcheck
# 19   female  NaN      0      0        2649   7.2250   NaN        C  testcheck
# 26     male  NaN      0      0        2631   7.2250   NaN        C  testcheck
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  testcheck
# ..      ...  ...    ...    ...         ...      ...   ...      ...        ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  testcheck
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  testcheck
# 868    male  NaN      0      0      345777   9.5000   NaN        S  testcheck
# 878    male  NaN      0      0      349217   7.8958   NaN        S  testcheck
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  testcheck
#
# [177 rows x 13 columns]

# %%
df.loc[df[df['Age'].isnull() == True].index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked    testcol
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  testcheck
# 17     male  NaN      0      0      244373  13.0000   NaN        S  testcheck
# 19   female  NaN      0      0        2649   7.2250   NaN        C  testcheck
# 26     male  NaN      0      0        2631   7.2250   NaN        C  testcheck
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  testcheck
# ..      ...  ...    ...    ...         ...      ...   ...      ...        ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  testcheck
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  testcheck
# 868    male  NaN      0      0      345777   9.5000   NaN        S  testcheck
# 878    male  NaN      0      0      349217   7.8958   NaN        S  testcheck
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  testcheck
#
# [177 rows x 13 columns]

# %%
df[df['Fare']==df['Fare'].max()]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#        testcol
# 258  testcheck
# 679  testcheck
# 737  testcheck

# %%
#1 . Find out how many male and female passenger was onboarded .

df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# 2. how many survived we have .

len(df[df['Survived']==1])
# Out:
# 342

# %%
# 4 . what is name of a person who is the eldest one . 

df[df['Age']  == df['Age'].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked    testcol
# 630  male  80.0      0      0  27042  30.0   A23        S  testcheck

# %%
# 5 . how many passenger do we have in first , second and third class 

df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 6. how many person we have whose name starts with "s"

len(df[df['Name'].str.startswith('S')])
# Out:
# 86

# %%
# 7. try to create a new column which is a summation  of "SibSp" and "parch"

df['SumSibSpParch'] = df['SibSp'] + df ['Parch']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked    testcol  SumSibSpParch
# 0        0         A/5 21171   7.2500   NaN        S  testcheck              1
# 1        0          PC 17599  71.2833   C85        C  testcheck              1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  testcheck              0
# 3        0            113803  53.1000  C123        S  testcheck              1
# 4        0            373450   8.0500   NaN        S  testcheck              0
# ..     ...               ...      ...   ...      ...        ...            ...
# 886      0            211536  13.0000   NaN        S  testcheck              0
# 887      0            112053  30.0000   B42        S  testcheck              0
# 888      2        W./C. 6607  23.4500   NaN        S  testcheck              3
# 889      0            111369  30.0000  C148        C  testcheck              0
# 890      0            370376   7.7500   NaN        Q  testcheck              0
#
# [891 rows x 14 columns]

# %%
# 8 . how many person do we have below age of 25 .

len(df[df['Age'] < 25])
# Out:
# 278

# %%
# 9 . how many person died whose age was less then 40 

df[(df['Survived'] == 0) & (df['Age'] < 40)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.250   NaN        S
# 4      male  35.0      0      0            373450   8.050   NaN        S
# 7      male   2.0      3      1            349909  21.075   NaN        S
# 12     male  20.0      0      0         A/5. 2151   8.050   NaN        S
# 13     male  39.0      1      5            347082  31.275   NaN        S
# ..      ...   ...    ...    ...               ...     ...   ...      ...
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5            382652  29.125   NaN        Q
# 886    male  27.0      0      0            211536  13.000   NaN        S
# 890    male  32.0      0      0            370376   7.750   NaN        Q
#
#        testcol  SumSibSpParch
# 0    testcheck              1
# 4    testcheck              0
# 7    testcheck              4
# 12   testcheck              0
# 13   testcheck              6
# ..         ...            ...
# 883  testcheck              0
# 884  testcheck              0
# 885  testcheck              5
# 886  testcheck              0
# 890  testcheck              0
#
# [322 rows x 14 columns]

# %%
#10 . from a  cabin column seperate text and numeric value . 

df['Cabin'].dropna(inplace=True)
df['Cabin'].str.extract("([a-zA-Z]+)([^a-zA-Z]+)")
# Out:
#      0    1
# 1    C   85
# 3    C  123
# 6    E   46
# 10   G    6
# 11   C  103
# ..  ..  ...
# 871  D   35
# 872  B  51
# 879  C   50
# 887  B   42
# 889  C  148
#
# [204 rows x 2 columns]

# %%
df['Cabin'].sp
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
3. how many casuality we have
