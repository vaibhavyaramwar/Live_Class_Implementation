# %%
import mysql.connector as connection

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",use_pure=True)
    print("Connection Status : ",myDb.is_connected())
    query = "show databases"
    cursor=myDb.cursor()
    cursor.execute(query)
    
    print("Current Databases Exists: ")
    print("===========================================================================================================")
    for i in cursor.fetchall():
        print(i[0])
        
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# Connection Status :  True
# Current Databases Exists:
# ...
# information_schema
# mysql
# performance_schema
# student
# studentnew
# sys
# testdb

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",use_pure=True)
    print("Connection Status : ",myDb.is_connected())
    query = "show databases"
    cursor=myDb.cursor()
    cursor.execute(query)
    
    print("Current Databases Exists: ")
    print("===========================================================================================================")
    for i in cursor.fetchall():
        if i[0] == "student":
            print("Student Database exists")
        
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# Connection Status :  True
# Current Databases Exists:
# ...
# Student Database exists

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",use_pure=True)
    
    cursor=myDb.cursor()
    cursor.execute("create database testDb")
    
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# 1007 (HY000): Can't create database 'testdb'; database exists

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testDb",use_pure=True)
    query = "create table if not exists ineuron(studentid int(10),firstname varchar(60),lastname varchar(60),registrationid int(10),classname varchar(10))"
    cursor=myDb.cursor()
    cursor.execute(query)
    cursor.execute("show tables")
    print(cursor.fetchall())
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# [('cardata',), ('glassdata',), ('ineuron',)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testDb",use_pure=True)
   # query = "INSERT INTO ineuron('studentid','firstname','lastname','registrationid','classname') VALUES (1,'Vaibhav','Yaramwar',11111,'FSDS')"
    cursor=myDb.cursor()
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(1,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(2,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(3,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(4,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(5,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(6,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(7,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(8,"Vaibhav","Yaramwar",11111,"FSDS")')
    cursor.execute('INSERT INTO ineuron(studentid,firstname,lastname,registrationid,classname) VALUES(9,"Vaibhav","Yaramwar",11111,"FSDS")')
    print(cursor.rowcount)
    myDb.commit()
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# 1

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testDb",use_pure=True)
   # query = "INSERT INTO ineuron('studentid','firstname','lastname','registrationid','classname') VALUES (1,'Vaibhav','Yaramwar',11111,'FSDS')"
    cursor=myDb.cursor()
    cursor.execute("select * from ineuron")
    
    for result in cursor.fetchall():
        print(result)
        
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# (1, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (1, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (2, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (3, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (4, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (5, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (6, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (7, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (8, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (9, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (1, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (2, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (3, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (4, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (5, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (6, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (7, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (8, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')
# (9, 'Vaibhav', 'Yaramwar', 11111, 'FSDS')

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testDb",use_pure=True)
    query = "create table if not exists glassdata(col1 int(10),col2 float(10,5) ,col3 float(10,5),col4 float(10,5),col5 float(10,5),col6 float(10,5),col7 float(10,5),col8 float(10,5),col9 float(10,5),col10 float(10,5),col11 int(10))"
    cursor=myDb.cursor()
    cursor.execute(query)
    cursor.execute("show tables")
    print(cursor.fetchall())
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# [('glassdata',), ('ineuron',)]

# %%
import csv

try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testDb",use_pure=True)
    
    with open("glass.data","r") as data:
        print(data)
        readData = csv.reader(data,delimiter="\n")
        cursor=myDb.cursor()
        
        for result in readData:
            #print(result[0])
            print('INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES ({data})'.format(data=(result[0])))
            cursor.execute('INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES ({data})'.format(data=(result[0])))
            myDb.commit()
    #  cursor.execute("show tables")
  #  print(cursor.fetchall())
  #  myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# <_io.TextIOWrapper name='glass.data' mode='r' encoding='cp1252'>
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# INSERT INTO glassdata(col1,col2,col3,col4,col5,col6,col7,col8,col9,col10,col11) VALUES (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# ...

# %%
import pandas as pd

# %%
pd.read_sql("select * from testdb.glassdata",myDb)
# Out:
#      col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 2       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 3       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# 4       5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 423   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# 424   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.0      7
# 425   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.0      7
# 426   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.0      7
# 427   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.0      7
#
# [428 rows x 11 columns]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("delete from glassdata where col1 > 214")
    myDb.commit()
except Exception as e:
    print(e)

# %%
pd.read_sql("show tables",myDb)
# Out:
#   Tables_in_testdb
# 0        glassdata
# 1          ineuron

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata where col1 < 5")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1), (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1), (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1), (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1), (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1), (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1), (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1), (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata where col1 =1")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1), (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("update glassdata set col5 = 5.3534534534  where col1 =1")
    myDb.commit()
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# []

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata where col1 =1")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 13.64, 4.49, 5.35345, 71.78, 0.06, 8.75, 0.0, 0.0, 1), (1, 1.52101, 13.64, 4.49, 5.35345, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select col1,col2,count(1) from glassdata where col1 < 50 group by col1,col2")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 2), (2, 1.51761, 2), (3, 1.51618, 2), (4, 1.51766, 2), (5, 1.51742, 2), (6, 1.51596, 2), (7, 1.51743, 2), (8, 1.51756, 2), (9, 1.51918, 2), (10, 1.51755, 2), (11, 1.51571, 2), (12, 1.51763, 2), (13, 1.51589, 2), (14, 1.51748, 2), (15, 1.51763, 2), (16, 1.51761, 2), (17, 1.51784, 2), (18, 1.52196, 2), (19, 1.51911, 2), (20, 1.51735, 2), (21, 1.5175, 2), (22, 1.51966, 2), (23, 1.51736, 2), (24, 1.51751, 2), (25, 1.5172, 2), (26, 1.51764, 2), (27, 1.51793, 2), (28, 1.51721, 2), (29, 1.51768, 2), (30, 1.51784, 2), (31, 1.51768, 2), (32, 1.51747, 2), (33, 1.51775, 2), (34, 1.51753, 2), (35, 1.51783, 2), (36, 1.51567, 2), (37, 1.51909, 2), (38, 1.51797, 2), (39, 1.52213, 2), (40, 1.52213, 2), (41, 1.51793, 2), (42, 1.51755, 2), (43, 1.51779, 2), (44, 1.5221, 2), (45, 1.51786, 2), (46, 1.519, 2), (47, 1.51869, 2), (48, 1.52667, 2), (49, 1.52223, 2)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select col1,col2,col11 from glassdata where col1 =1 or col11=2")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 1), (71, 1.51574, 2), (72, 1.51848, 2), (73, 1.51593, 2), (74, 1.51631, 2), (75, 1.51596, 2), (76, 1.5159, 2), (77, 1.51645, 2), (78, 1.51627, 2), (79, 1.51613, 2), (80, 1.5159, 2), (81, 1.51592, 2), (82, 1.51593, 2), (83, 1.51646, 2), (84, 1.51594, 2), (85, 1.51409, 2), (86, 1.51625, 2), (87, 1.51569, 2), (88, 1.51645, 2), (89, 1.51618, 2), (90, 1.5164, 2), (91, 1.51841, 2), (92, 1.51605, 2), (93, 1.51588, 2), (94, 1.5159, 2), (95, 1.51629, 2), (96, 1.5186, 2), (97, 1.51841, 2), (98, 1.51743, 2), (99, 1.51689, 2), (100, 1.51811, 2), (101, 1.51655, 2), (102, 1.5173, 2), (103, 1.5182, 2), (104, 1.52725, 2), (105, 1.5241, 2), (106, 1.52475, 2), (107, 1.53125, 2), (108, 1.53393, 2), (109, 1.52222, 2), (110, 1.51818, 2), (111, 1.52664, 2), (112, 1.52739, 2), (113, 1.52777, 2), (114, 1.51892, 2), (115, 1.51847, 2), (116, 1.51846, 2), (117, 1.51829, 2), (118, 1.51708, 2), (119, 1.51673, 2), (120, 1.51652, 2), (121, 1.51844, 2), (122, 1.51663, 2), (123, 1.51687, 2), (124, 1.51
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select col1,col2,col11 from glassdata where col1 =1 and col11=2")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# []

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select col1,col2,col11 from glassdata where col2 like '1.51%'")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(2, 1.51761, 1), (3, 1.51618, 1), (4, 1.51766, 1), (5, 1.51742, 1), (6, 1.51596, 1), (7, 1.51743, 1), (8, 1.51756, 1), (9, 1.51918, 1), (10, 1.51755, 1), (11, 1.51571, 1), (12, 1.51763, 1), (13, 1.51589, 1), (14, 1.51748, 1), (15, 1.51763, 1), (16, 1.51761, 1), (17, 1.51784, 1), (19, 1.51911, 1), (20, 1.51735, 1), (21, 1.5175, 1), (22, 1.51966, 1), (23, 1.51736, 1), (24, 1.51751, 1), (25, 1.5172, 1), (26, 1.51764, 1), (27, 1.51793, 1), (28, 1.51721, 1), (29, 1.51768, 1), (30, 1.51784, 1), (31, 1.51768, 1), (32, 1.51747, 1), (33, 1.51775, 1), (34, 1.51753, 1), (35, 1.51783, 1), (36, 1.51567, 1), (37, 1.51909, 1), (38, 1.51797, 1), (41, 1.51793, 1), (42, 1.51755, 1), (43, 1.51779, 1), (45, 1.51786, 1), (46, 1.519, 1), (47, 1.51869, 1), (50, 1.51898, 1), (52, 1.51926, 1), (53, 1.51808, 1), (54, 1.51837, 1), (55, 1.51778, 1), (56, 1.51769, 1), (57, 1.51215, 1), (58, 1.51824, 1), (59, 1.51754, 1), (60, 1.51754, 1), (61, 1.51905, 1), (62, 1.51977, 1), (71, 1.51574, 2), (72, 1.51848, 2), (
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata order by col2")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6), (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6), (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7), (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7), (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1), (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1), (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6), (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6), (172, 1.51316, 13.02, 0.0, 3.04, 70.48, 6.21, 6.96, 0.0, 0.0, 5), (172, 1.51316, 13.02, 0.0, 3.04, 70.48, 6.21, 6.96, 0.0, 0.0, 5), (173, 1.51321, 13.0, 0.0, 3.02, 70.7, 6.21, 6.93, 0.0, 0.0, 5), (173, 1.51321, 13.0, 0.0, 3.02, 70.7, 6.21, 6.93, 0.0, 0.0, 5), (85, 1.51409, 14.25, 3.09, 2.08, 72.28, 1.1, 7.08, 0.0, 0.0, 2), (85, 1.51409, 14.25, 3.09, 2.08, 72.28, 1.1, 7.08, 0.0, 0.0, 2), (201, 1.51508, 15.15, 0.0, 2.25, 73.5, 0.0, 8.34, 0.63, 0.0, 7), (201, 1.51508,
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata order by col2 desc")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2), (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2), (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2), (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2), (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2), (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2), (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2), (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2), (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2), (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2), (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1), (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1), (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2), (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2), (132, 1.52614, 13.7, 0.0, 1.36, 71.24, 0.19, 13.44, 0.0, 0.1, 2), (132,
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata order by col2 desc")
    print(cursor.fetchall())
except Exception as e:
    print(e)

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from (select * from glassData where col1 > 112) gsData where col11=3")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3), (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3), (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3), (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3), (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3), (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3), (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3), (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3), (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3), (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3), (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3), (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3), (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3), (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3), (161, 1.51832, 13.33, 3.34, 1.54, 72.14, 0.56, 8.99, 0.0, 0.0, 3), (16
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="testdb",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("select * from glassdata group by col1 having count(col1) >1")
    print(cursor.fetchall())
except Exception as e:
    print(e)
# Out:
# [(1, 1.52101, 13.64, 4.49, 5.35345, 71.78, 0.06, 8.75, 0.0, 0.0, 1), (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1), (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1), (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1), (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1), (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1), (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1), (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1), (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1), (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1), (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1), (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1), (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1), (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1), (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1), (16, 1.51761, 12.81,
# ...

# %%
'''
1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
2 . create a database called as cardataset
3 . create a table called as car with a column name given in dataset description
4 . Dump all the data into car table 
5 . try to check weather all the data is aviable inside your table or not 
6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value 
7 . Try to filter a record where col 3 value will be 4 .
8.  Try to update a col 3 value with 8 whereever you have value equal to 2 
9 . try to delete table 
10 .   Try to delete database
'''
# Out:
# '\n1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation\n2 . create a database called as cardataset\n3 . create a table called as car with a column name given in dataset description\n4 . Dump all the data into car table \n5 . try to check weather all the data is aviable inside your table or not \n6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value \n7 . Try to filter a record where col 3 value will be 4 .\n8.  Try to update a col 3 value with 8 whereever you have value equal to 2 \n9 . try to delete table \n10 .   Try to delete database\n'

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("drop database cardataset")
    cursor.execute("create database cardataset")
    cursor.execute("show databases")
    print(cursor.fetchall())
    cursor.close()
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# [('cardataset',), ('information_schema',), ('mysql',), ('performance_schema',), ('student',), ('studentnew',), ('sys',), ('testdb',)]

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("create table if not exists carData(buying   varchar(20),maint varchar(20),doors    varchar(20),persons  varchar(20),lug_boot varchar(20),safety   varchar(20),class     varchar(20))")
    cursor.execute("show tables")
    print(cursor.fetchall())
    cursor.close()
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# [('cardata',)]

# %%
import csv

try:
     myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
     
     with open("car.data","r") as data: 
            carData = csv.reader(data,delimiter="\n")
            for cData in carData:
                #print(cData[0].split(","))
                cursor = myDb.cursor()
                carData=(str(cData[0].split(",")))
                #print(str(cData[0].split(","))[1:len(carData)-1])
                print('INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ({carData})'.format(carData=str(cData[0].split(","))[1:len(carData)-1]))
                cursor.execute('INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ({carData})'.format(carData=str(cData[0].split(","))[1:len(carData)-1]))
                myDb.commit()
except Exception as e:
    print(e)
# Out:
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc')
# INSERT INTO cardata(buying,maint,doors,persons,lug_boot,safety,class) VALUES ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc')
# ...

# %%
try:
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor = myDb.cursor()
    cursor.execute("select * from cardata")
    for result in cursor.fetchall():
        print(result)
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '2', '4', 'big', 'high', 'unacc')
# ...

# %%
try:
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor = myDb.cursor()
    cursor.execute("select buying,count(buying) from cardata group by buying")
    for result in cursor.fetchall():
        print(result)
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# ('vhigh', 432)
# ('high', 432)
# ('med', 432)
# ('low', 432)

# %%
try:
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor = myDb.cursor()
    cursor.execute('select * from cardata where doors = "4"')
    for result in cursor.fetchall():
        print(result)
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# ('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '4', '4', 'big', 'high', 'unacc')
# ...

# %%
try:
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor = myDb.cursor()
    cursor.execute('update cardata set doors = "8" where doors = "2"')
    myDb.commit()
    cursor.execute('select * from cardata where doors = "8"')
    for result in cursor.fetchall():
        print(result)
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# ('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc')
# ('vhigh', 'vhigh', '8', '4', 'big', 'high', 'unacc')
# ...

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",database="cardataset",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("drop table cardata")
    cursor.execute("show tables")
    print(cursor.fetchall())
    cursor.close()
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# []

# %%
try:
    
    myDb = connection.connect(host="localhost",port=5506,user="root",password="mysql",use_pure=True)
    cursor=myDb.cursor()
    cursor.execute("drop database cardataset")
    cursor.execute("show databases")
    print(cursor.fetchall())
    cursor.close()
    myDb.close()
except Exception as e:
    myDb.close()
    print(e)
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('student',), ('studentnew',), ('sys',), ('testdb',)]
